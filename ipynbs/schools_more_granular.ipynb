# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
crimes = pd.read_csv("csvs/Crimes_and_Clearances_with_Arson-1985-2016.csv")
schools = pd.read_csv("csvs/new_district.csv")
places = pd.read_csv("csvs/htaindex_data_places_06.csv")
places_info = gpd.read_file("tl_2017_06_place/tl_2017_06_place.shp")
# Out:
# /Users/kanamishra/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (21,22,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
crimes.columns
# Out:
# Index(['Year', 'County', 'NCICCode', 'Violent_sum', 'Homicide_sum',
#        'ForRape_sum', 'Robbery_sum', 'AggAssault_sum', 'Property_sum',
#        'Burglary_sum', 'VehicleTheft_sum', 'LTtotal_sum', 'ViolentClr_sum',
#        'HomicideClr_sum', 'ForRapeClr_sum', 'RobberyClr_sum',
#        'AggAssaultClr_sum', 'PropertyClr_sum', 'BurglaryClr_sum',
#        'VehicleTheftClr_sum', 'LTtotalClr_sum', 'TotalStructural_sum',
#        'TotalMobile_sum', 'TotalOther_sum', 'GrandTotal_sum',
#        'GrandTotClr_sum', 'RAPact_sum', 'ARAPact_sum', 'FROBact_sum',
#        'KROBact_sum', 'OROBact_sum', 'SROBact_sum', 'HROBnao_sum',
#        'CHROBnao_sum', 'GROBnao_sum', 'CROBnao_sum', 'RROBnao_sum',
#        'BROBnao_sum', 'MROBnao_sum', 'FASSact_sum', 'KASSact_sum',
#        'OASSact_sum', 'HASSact_sum', 'FEBURact_Sum', 'UBURact_sum',
#        'RESDBUR_sum', 'RNBURnao_sum', 'RDBURnao_sum', 'RUBURnao_sum',
#        'NRESBUR_sum', 'NNBURnao_sum', 'NDBURnao_sum', 'NUBURnao_sum',
# ...

# %%
crimes = crimes[crimes['Year'] == 2016]

# %%
crimes.head()
# Out:
#        Year          County                          NCICCode  Violent_sum  \
# 22759  2016  Alameda County  Alameda Co. Sheriff's Department          589
# 22760  2016  Alameda County                           Alameda          151
# 22761  2016  Alameda County                            Albany           29
# 22762  2016  Alameda County                          Berkeley          602
# 22763  2016  Alameda County                        Emeryville          132
#
#        Homicide_sum  ForRape_sum  Robbery_sum  AggAssault_sum  Property_sum  \
# 22759             8           30          204             347          2195
# 22760             1            8           68              74          2020
# 22761             0            0           24               5           533
# 22762             2           54          361             185          5420
# 22763             0            3           97              32          1721
#
# ...

# %%
len(crimes)
# Out:
# 732

# %%
crimes_by_city = crimes.groupby("NCICCode").aggregate(sum).reset_index()
crimes_by_city.head()
# Out:
#                            NCICCode  Year  Violent_sum  Homicide_sum  \
# 0                          Adelanto  2016          276             1
# 1                      Agoura Hills  2016           15             0
# 2                           Alameda  2016          151             1
# 3                      Alameda BART  2016          184             1
# 4  Alameda Co. Sheriff's Department  2016          589             8
#
#    ForRape_sum  Robbery_sum  AggAssault_sum  Property_sum  Burglary_sum  \
# 0           28           48             199           560           241
# 1            2            3              10           253            83
# 2            8           68              74          2020           226
# 3            1          148              34          1560             5
# 4           30          204             347          2195           490
#
#    VehicleTheft_sum     ...       MVLARnao_sum  MVPLARnao_sum  BILARnao_sum  \
# ...

# %%
len(crimes_by_city)
# Out:
# 732

# %%
crimes_by_city = crimes_by_city[['NCICCode', 'Violent_sum', 'Property_sum']]
crimes_by_city
# Out:
#                              NCICCode  Violent_sum  Property_sum
# 0                            Adelanto          276           560
# 1                        Agoura Hills           15           253
# 2                             Alameda          151          2020
# 3                        Alameda BART          184          1560
# 4    Alameda Co. Sheriff's Department          589          2195
# 5     Alameda E. Bay Mun. Util. Dist.            0            27
# 6      Alameda E. Bay Reg. Park Dist.           13           110
# 7                              Albany           29           533
# 8                            Alhambra          146          2107
# 9                         Aliso Viejo           29           411
# 10              Allen Hancock College            0            15
# 11    Alpine Co. Sheriff's Department            6            34
# 12                            Alturas           22           116
# ...

# %%
# check validity
crimes_by_city[crimes_by_city['NCICCode'] == 'Dublin']
# Out:
#     NCICCode  Violent_sum  Property_sum
# 222   Dublin           87          1097

# %%
schools.columns
# Out:
# Index(['Unnamed: 0', 'index', 'Rank', 'District', 'Grades',
#        '# Elementary Schools', '# Middle Schools', '# High Schools',
#        '# Alt. Schools', 'City', 'County', 'Rank score (2017)', 'Rank (2016)',
#        'rank'],
#       dtype='object')

# %%
schools.head()
# Out:
#    Unnamed: 0  index Rank                    District Grades  \
# 0           0      0  1st     Orinda Union Elementary    K-8
# 1           1      1  2nd          San Marino Unified   K-12
# 2           2      2  3rd  Rancho Santa Fe Elementary    K-8
# 3           3      3  4th  Montecito Union Elementary    K-6
# 4           4      4  5th           La Canada Unified   K-12
#
#    # Elementary Schools  # Middle Schools  # High Schools  # Alt. Schools  \
# 0                     4                 1               0               0
# 1                     2                 1               1               0
# 2                     1                 1               0               0
# 3                     1                 0               0               0
# 4                     3                 0               1               0
#
#               City         County  Rank score (2017)  Rank (2016)  rank
# 0           Orinda   Contra Costa              0.989          3.0     1
# ...

# %%
# schools_by_city = schools.groupby("City").aggregate(np.mean).reset_index()
# schools_by_city.fillna(0, inplace=True)
# schools_by_city.rename(columns={'Rank score (2017)':'score'}, inplace=True)
# schools_by_city = schools_by_city[['City', 'score', 'rank']]
# schools_by_city
# Out:
#                  City     score        rank
# 0              Acampo  0.683000  224.000000
# 1               Acton  0.389000  593.000000
# 2            Adelanto  0.135000  819.000000
# 3             Alameda  0.733000  166.000000
# 4              Albany  0.944000   32.000000
# 5            Alhambra  0.732000  170.000000
# 6             Alpaugh  0.294000  706.000000
# 7              Alpine  0.662000  246.000000
# 8                Alta  0.744000  157.000000
# 9           Alta Loma  0.763000  138.000000
# 10            Alturas  0.355000  210.333333
# 11            Anaheim  0.482750  363.600000
# 12           Anderson  0.488000  153.666667
# 13        Angels Camp  0.509000  141.333333
# 14             Angwin  0.000000    0.000000
# 15          Annapolis  0.000000    0.000000
# 16           Antelope  0.515000  417.000000
# 17            Antioch  0.309000  682.000000
# 18       Apple Valley  0.372000  607.000000
# 19           Arbuckle  0.378000  602.000000
# ...

# %%
places['place'] = places['place'].apply(lambda k: k[1:-1])

# %%
places['name'] = places['name'].apply(lambda k: k[1:-1])

# %%
print(places.columns)
places.head()
# Out:
# Index(['place', 'name', 'blkgrps', 'population', 'households', 'land_acres',
#        'ht_ami', 'ht_80ami', 'ht_nmi', 'h_ami', 'h_80ami', 'h_nmi', 't_ami',
#        't_80ami', 't_nmi', 'co2_per_hh_local', 'co2_per_acre_local',
#        'autos_per_hh_ami', 'autos_per_hh_80ami', 'autos_per_hh_nmi',
#        'vmt_per_hh_ami', 'vmt_per_hh_80ami', 'vmt_per_hh_nmi',
#        'pct_transit_commuters_ami', 'pct_transit_commuters_80ami',
#        'pct_transit_commuters_nmi', 't_cost_ami', 't_cost_80ami', 't_cost_nmi',
#        'auto_ownership_cost_ami', 'auto_ownership_cost_80ami',
#        'auto_ownership_cost_nmi', 'vmt_cost_ami', 'vmt_cost_80ami',
#        'vmt_cost_nmi', 'transit_cost_ami', 'transit_cost_80ami',
#        'transit_cost_nmi', 'transit_trips_ami', 'transit_trips_80ami',
#        'transit_trips_nmi', 'compact_ndx', 'emp_ovrll_ndx', 'res_density',
#        'gross_hh_density', 'hh_gravity', 'frac_sfd', 'emp_gravity', 'emp_ndx',
# ...

# %%
print(places_info.columns)
places_info.head()
# Out:
# Index(['STATEFP', 'PLACEFP', 'PLACENS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',
#        'CLASSFP', 'PCICBSA', 'PCINECTA', 'MTFCC', 'FUNCSTAT', 'ALAND',
#        'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')
#   STATEFP PLACEFP   PLACENS    GEOID                        NAME  \
# 0      06   66140  02411785  0666140                San Fernando
# 1      06   14190  02409487  0614190                  Cloverdale
# 2      06   16560  02410240  0616560                      Cotati
# 3      06   65042  02411779  0665042  San Buenaventura (Ventura)
# 4      06   30014  02410601  0630014                    Glendora
#
#                           NAMELSAD LSAD CLASSFP PCICBSA PCINECTA  MTFCC  \
# 0                San Fernando city   25      C1       N        N  G4110
# 1                  Cloverdale city   25      C1       N        N  G4110
# 2                      Cotati city   25      C1       N        N  G4110
# ...

# %%
#check validity
places_info[places_info['NAME'] == 'Dublin']
# Out:
#     STATEFP PLACEFP   PLACENS    GEOID    NAME     NAMELSAD LSAD CLASSFP  \
# 352      06   20018  02410362  0620018  Dublin  Dublin city   25      C1
#
#     PCICBSA PCINECTA  MTFCC FUNCSTAT     ALAND  AWATER     INTPTLAT  \
# 352       N        N  G4110        A  39453264       0  +37.7161535
#
#          INTPTLON                                           geometry
# 352  -121.8962343  POLYGON ((-121.987797 37.709318, -121.978826 3...

# %%
places_geo = places_info[['GEOID', 'geometry']]
places_geo.head()
# Out:
#      GEOID                                           geometry
# 0  0666140  POLYGON ((-118.456008 34.284903, -118.454141 3...
# 1  0614190  POLYGON ((-123.035115 38.787005, -123.035093 3...
# 2  0616560  POLYGON ((-122.729598 38.333486, -122.729512 3...
# 3  0665042  (POLYGON ((-119.297103 34.344633, -119.297012 ...
# 4  0630014  POLYGON ((-117.891093 34.14581, -117.89064 34....

# %%
hta_with_geo = pd.merge(places, places_geo, how='left', left_on='place', right_on='GEOID')
hta_with_geo.drop('GEOID', axis=1, inplace=True)
hta_with_geo.head()
# Out:
#      place            name  blkgrps  population  households  land_acres  \
# 0  0600135  Acalanes Ridge     0.91     1260.63      454.57      294.81
# 1  0600156          Acampo     0.08      127.55       44.51      598.35
# 2  0600212           Acton     1.94     4673.42     1578.34    25128.28
# 3  0600296        Adelanto     8.42    29471.00     7400.73    35834.64
# 4  0600310            Adin     0.01        4.52        1.83     2196.64
#
#    ht_ami  ht_80ami  ht_nmi  h_ami  \
# 0    58.0      70.0    86.0   41.0
# 1    54.0      64.0    53.0   22.0
# 2    83.0      99.0    90.0   52.0
# 3    52.0      62.0    52.0   25.0
# 4    71.0      86.0    55.0   30.0
#
#                          ...                          emp_ndx  block_size  \
# 0                        ...                               90          12
# 1                        ...                               88          82
# 2                        ...                               88          63
# ...

# %%
schools_with_crimes = pd.merge(schools, crimes_by_city, how='left', left_on='City', right_on='NCICCode')
schools_with_crimes.drop(['NCICCode', 'Unnamed: 0'], axis = 1, inplace=True)
schools_with_crimes.head()
# Out:
#    index Rank                    District Grades  # Elementary Schools  \
# 0      0  1st     Orinda Union Elementary    K-8                     4
# 1      1  2nd          San Marino Unified   K-12                     2
# 2      2  3rd  Rancho Santa Fe Elementary    K-8                     1
# 3      3  4th  Montecito Union Elementary    K-6                     1
# 4      4  5th           La Canada Unified   K-12                     3
#
#    # Middle Schools  # High Schools  # Alt. Schools             City  \
# 0                 1               0               0           Orinda
# 1                 1               1               0       San Marino
# 2                 1               0               0  Rancho Santa Fe
# 3                 0               0               0    Santa Barbara
# 4                 0               1               0        La Canada
#
#           County  Rank score (2017)  Rank (2016)  rank  Violent_sum  \
# ...

# %%
schools_full = pd.merge(schools_with_crimes, hta_with_geo, how = 'left', left_on='City', right_on='name')
schools_full.drop('name', axis=1, inplace=True)
schools_full.head()
# Out:
#    index Rank                    District Grades  # Elementary Schools  \
# 0      0  1st     Orinda Union Elementary    K-8                     4
# 1      1  2nd          San Marino Unified   K-12                     2
# 2      2  3rd  Rancho Santa Fe Elementary    K-8                     1
# 3      3  4th  Montecito Union Elementary    K-6                     1
# 4      4  5th           La Canada Unified   K-12                     3
#
#    # Middle Schools  # High Schools  # Alt. Schools             City  \
# 0                 1               0               0           Orinda
# 1                 1               1               0       San Marino
# 2                 1               0               0  Rancho Santa Fe
# 3                 0               0               0    Santa Barbara
# 4                 0               1               0        La Canada
#
#           County                        ...                          emp_ndx  \
# ...

# %%
schools_full.isnull().sum()
# Out:
# index                           0
# Rank                          246
# District                        0
# Grades                          1
# # Elementary Schools            0
# # Middle Schools                0
# # High Schools                  0
# # Alt. Schools                  0
# City                            0
# County                          0
# Rank score (2017)             246
# Rank (2016)                   265
# rank                            0
# Violent_sum                   359
# Property_sum                  359
# place                          72
# blkgrps                        72
# population                     72
# households                     72
# land_acres                     72
# ht_ami                         72
# ht_80ami                       72
# ht_nmi                         72
# h_ami                          72
# h_80ami                        72
# h_nmi                          72
# t_ami                          72
# ...

# %%
schools_full.to_csv("schools_full.csv")
