# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ct = pd.read_csv("../csvs/htaindex_data_tracts_06.csv")
crimes = pd.read_csv("../csvs/crimes.csv")
schools = pd.read_csv("../csvs/new_district.csv")
ct_info = gpd.read_file("../tl_2017_06_tract/tl_2017_06_tract.shp")

# %%
ct.tract = ct.tract.apply(lambda k: k[1:-1])
ct.head()
# Out:
#          tract  blkgrps  population  households  land_acres  ht_ami  ht_80ami  \
# 0  06001400100      1.0      2952.0      1286.0     1703.63    76.0      92.0
# 1  06001400200      2.0      1984.0       832.0      145.16    54.0      66.0
# 2  06001400300      4.0      5377.0      2489.0      273.13    44.0      53.0
# 3  06001400400      3.0      4105.0      1801.0      176.61    45.0      54.0
# 4  06001400500      3.0      3651.0      1624.0      145.87    41.0      50.0
#
#    ht_nmi  h_ami  h_80ami           ...            emp_gravity  emp_ndx  \
# 0   112.0   57.0     71.0           ...                44078.0     92.0
# 1    80.0   38.0     48.0           ...                69965.0     93.0
# 2    64.0   29.0     36.0           ...                81494.0     93.0
# 3    65.0   30.0     37.0           ...                76587.0     93.0
# 4    61.0   27.0     34.0           ...                81371.0     94.0
#
#    block_size  intersection_density  avg_block_perimeter_meters  h_cost  \
# 0        21.0                  70.0                        1334  3848.0
# 1         4.0                 383.0                         542  2605.0
# 2         3.0                 478.0                         529  1973.0
# 3         3.0                 408.0                         457  2036.0
# 4         3.0                 405.0                         487  1836.0
#
#    median_smoc  median_gross_rent  pct_owner_occupied_hu  \
# 0       4001.0             2944.0                   86.0
# 1       3097.0             1775.0                   64.0
# 2       3097.0             1077.0                   44.0
# 3       2302.0             1537.0                   38.0
# 4       2686.0             1354.0                   36.0
#
#    pct_renter_occupied_hu
# 0                    14.0
# 1                    36.0
# 2                    56.0
# 3                    62.0
# 4                    64.0
#
# [5 rows x 56 columns]

# %%
ct.columns
# Out:
# Index(['tract', 'blkgrps', 'population', 'households', 'land_acres', 'ht_ami',
#        'ht_80ami', 'ht_nmi', 'h_ami', 'h_80ami', 'h_nmi', 't_ami', 't_80ami',
#        't_nmi', 'co2_per_hh_local', 'co2_per_acre_local', 'autos_per_hh_ami',
#        'autos_per_hh_80ami', 'autos_per_hh_nmi', 'vmt_per_hh_ami',
#        'vmt_per_hh_80ami', 'vmt_per_hh_nmi', 'pct_transit_commuters_ami',
#        'pct_transit_commuters_80ami', 'pct_transit_commuters_nmi',
#        't_cost_ami', 't_cost_80ami', 't_cost_nmi', 'auto_ownership_cost_ami',
#        'auto_ownership_cost_80ami', 'auto_ownership_cost_nmi', 'vmt_cost_ami',
#        'vmt_cost_80ami', 'vmt_cost_nmi', 'transit_cost_ami',
#        'transit_cost_80ami', 'transit_cost_nmi', 'transit_trips_ami',
#        'transit_trips_80ami', 'transit_trips_nmi', 'compact_ndx',
#        'emp_ovrll_ndx', 'res_density', 'gross_hh_density', 'hh_gravity',
#        'frac_sfd', 'emp_gravity', 'emp_ndx', 'block_size',
#        'intersection_density', 'avg_block_perimeter_meters', 'h_cost',
#        'median_smoc', 'median_gross_rent', 'pct_owner_occupied_hu',
#        'pct_renter_occupied_hu'],
#       dtype='object')

# %%
ct_info.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID     NAME              NAMELSAD  MTFCC  \
# 0      06      001  442700  06001442700     4427     Census Tract 4427  G5020
# 1      06      001  442800  06001442800     4428     Census Tract 4428  G5020
# 2      06      037  204920  06037204920  2049.20  Census Tract 2049.20  G5020
# 3      06      037  205110  06037205110  2051.10  Census Tract 2051.10  G5020
# 4      06      037  205120  06037205120  2051.20  Census Tract 2051.20  G5020
#
#   FUNCSTAT    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0        S  1234034       0  +37.5371514  -122.0081094
# 1        S  1278647       0  +37.5293619  -121.9931002
# 2        S   909972       0  +34.0175004  -118.1974975
# 3        S   286962       0  +34.0245059  -118.2142985
# 4        S  1466129       0  +34.0187546  -118.2117956
#
#                                             geometry
# 0  POLYGON ((-122.017211 37.539323, -122.017186 3...
# 1  POLYGON ((-122.002301 37.529836, -122.002236 3...
# 2  POLYGON ((-118.202837 34.019657, -118.202829 3...
# 3  POLYGON ((-118.219635 34.026285, -118.219449 3...
# 4  POLYGON ((-118.220227 34.020564, -118.220183 3...

# %%
ct_info.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'TRACTCE', 'GEOID', 'NAME', 'NAMELSAD', 'MTFCC',
#        'FUNCSTAT', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')

# %%
ct_info_to_join = ct_info[['COUNTYFP', 'GEOID', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry']]

# %%
len(ct)
# Out:
# 8036

# %%
len(ct_info)
# Out:
# 8057

# %%
tracts = pd.merge(ct_info_to_join, ct, how='outer', left_on='GEOID', right_on='tract')
tracts.head()
# Out:
#   COUNTYFP        GEOID    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0      001  06001442700  1234034       0  +37.5371514  -122.0081094
# 1      001  06001442800  1278647       0  +37.5293619  -121.9931002
# 2      037  06037204920   909972       0  +34.0175004  -118.1974975
# 3      037  06037205110   286962       0  +34.0245059  -118.2142985
# 4      037  06037205120  1466129       0  +34.0187546  -118.2117956
#
#                                             geometry        tract  blkgrps  \
# 0  POLYGON ((-122.017211 37.539323, -122.017186 3...  06001442700      3.0
# 1  POLYGON ((-122.002301 37.529836, -122.002236 3...  06001442800      1.0
# 2  POLYGON ((-118.202837 34.019657, -118.202829 3...  06037204920      2.0
# 3  POLYGON ((-118.219635 34.026285, -118.219449 3...  06037205110      1.0
# 4  POLYGON ((-118.220227 34.020564, -118.220183 3...  06037205120      2.0
#
#    population           ...            emp_gravity  emp_ndx  block_size  \
# 0      3275.0           ...                36491.0     92.0        10.0
# 1      3056.0           ...                38710.0     93.0         8.0
# 2      2570.0           ...               115862.0     95.0         5.0
# 3      3826.0           ...               143759.0     96.0         6.0
# 4      3288.0           ...               131817.0     95.0         4.0
#
#    intersection_density  avg_block_perimeter_meters  h_cost  median_smoc  \
# 0                 237.0                      1145.0  2304.0       2581.0
# 1                 243.0                       688.0  2205.0       2303.0
# 2                 222.0                       714.0  1322.0       1605.0
# 3                 325.0                       830.0  1140.0          NaN
# 4                 210.0                       708.0   766.0          NaN
#
#    median_gross_rent  pct_owner_occupied_hu  pct_renter_occupied_hu
# 0             1294.0                   75.0                    25.0
# 1             1958.0                   71.0                    29.0
# 2             1067.0                   48.0                    52.0
# 3             1140.0                    0.0                   100.0
# 4              766.0                   12.0                    88.0
#
# [5 rows x 63 columns]

# %%
len(tracts)
# Out:
# 8057

# %%
counties = gpd.read_file("../tl_2017_us_county/tl_2017_us_county.shp")
counties.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD CLASSFP  \
# 0      31      039  00835841  31039     Cuming     Cuming County   06      H1
# 1      53      069  01513275  53069  Wahkiakum  Wahkiakum County   06      H1
# 2      35      011  00933054  35011    De Baca    De Baca County   06      H1
# 3      31      109  00835876  31109  Lancaster  Lancaster County   06      H1
# 4      31      129  00835886  31129   Nuckolls   Nuckolls County   06      H1
#
#    MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 0  G4020                              A  1477641638  10701538  +41.9158651
# 1  G4020                              A   680956787  61588406  +46.2946377
# 2  G4020                              A  6016761648  29147345  +34.3592729
# 3  G4020   339  30700                 A  2169252486  22867561  +40.7835474
# 4  G4020                              A  1489645186   1718484  +40.1764918
#
#        INTPTLON                                           geometry
# 0  -096.7885168  POLYGON ((-97.019516 42.004097, -97.019519 42....
# 1  -123.4244583  POLYGON ((-123.436394 46.238197, -123.447592 4...
# 2  -104.3686961  POLYGON ((-104.567387 33.997566, -104.567717 3...
# 3  -096.6886584  POLYGON ((-96.91059899999999 40.958407, -96.91...
# 4  -098.0468422  POLYGON ((-98.27366699999999 40.089399, -98.27...

# %%
counties.columns
# Out:
# Index(['STATEFP', 'COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD', 'LSAD',
#        'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT', 'ALAND',
#        'AWATER', 'INTPTLAT', 'INTPTLON', 'geometry'],
#       dtype='object')

# %%
ca_counties = counties[counties['STATEFP'] == '06']
ca_counties.drop("geometry", axis=1, inplace=True)
ca_counties.head()
# Out:
# /Users/kanamishra/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     STATEFP COUNTYFP  COUNTYNS  GEOID           NAME              NAMELSAD  \
# 8        06      091  00277310  06091         Sierra         Sierra County
# 325      06      067  00277298  06067     Sacramento     Sacramento County
# 329      06      083  00277306  06083  Santa Barbara  Santa Barbara County
# 346      06      009  01675885  06009      Calaveras      Calaveras County
# 394      06      111  00277320  06111        Ventura        Ventura County
#
#     LSAD CLASSFP  MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND  \
# 8     06      H1  G4020                              A  2468694586
# 325   06      H1  G4020   472  40900                 A  2499039655
# 329   06      H1  G4020        42200                 A  7084000622
# 346   06      H1  G4020                              A  2641829199
# 394   06      H1  G4020   348  37100                 A  4773302741
#
#          AWATER     INTPTLAT      INTPTLON
# 8      23299110  +39.5769252  -120.5219926
# 325    76217822  +38.4500161  -121.3404408
# 329  2729814515  +34.5370572  -120.0399729
# 346    43797662  +38.1838996  -120.5614415
# 394   946030569  +34.3587415  -119.1331432

# %%
ca_counties_to_merge = ca_counties[['COUNTYFP', 'COUNTYNS', 'GEOID', 'NAME', 'NAMELSAD']]

# %%
len(tracts_with_county)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8c52ffa68874> in <module>()
# ----> 1 len(tracts_with_county)
#
# NameError: name 'tracts_with_county' is not defined

# %%
tracts_with_county = pd.merge(tracts, ca_counties_to_merge, how='left', on='COUNTYFP')
tracts_with_county.head()
# Out:
#   COUNTYFP      GEOID_x    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0      001  06001442700  1234034       0  +37.5371514  -122.0081094
# 1      001  06001442800  1278647       0  +37.5293619  -121.9931002
# 2      037  06037204920   909972       0  +34.0175004  -118.1974975
# 3      037  06037205110   286962       0  +34.0245059  -118.2142985
# 4      037  06037205120  1466129       0  +34.0187546  -118.2117956
#
#                                             geometry        tract  blkgrps  \
# 0  POLYGON ((-122.017211 37.539323, -122.017186 3...  06001442700      3.0
# 1  POLYGON ((-122.002301 37.529836, -122.002236 3...  06001442800      1.0
# 2  POLYGON ((-118.202837 34.019657, -118.202829 3...  06037204920      2.0
# 3  POLYGON ((-118.219635 34.026285, -118.219449 3...  06037205110      1.0
# 4  POLYGON ((-118.220227 34.020564, -118.220183 3...  06037205120      2.0
#
#    population         ...          avg_block_perimeter_meters  h_cost  \
# 0      3275.0         ...                              1145.0  2304.0
# 1      3056.0         ...                               688.0  2205.0
# 2      2570.0         ...                               714.0  1322.0
# 3      3826.0         ...                               830.0  1140.0
# 4      3288.0         ...                               708.0   766.0
#
#    median_smoc  median_gross_rent  pct_owner_occupied_hu  \
# 0       2581.0             1294.0                   75.0
# 1       2303.0             1958.0                   71.0
# 2       1605.0             1067.0                   48.0
# 3          NaN             1140.0                    0.0
# 4          NaN              766.0                   12.0
#
#    pct_renter_occupied_hu  COUNTYNS  GEOID_y         NAME            NAMELSAD
# 0                    25.0  01675839    06001      Alameda      Alameda County
# 1                    29.0  01675839    06001      Alameda      Alameda County
# 2                    52.0  00277283    06037  Los Angeles  Los Angeles County
# 3                   100.0  00277283    06037  Los Angeles  Los Angeles County
# 4                    88.0  00277283    06037  Los Angeles  Los Angeles County
#
# [5 rows x 67 columns]

# %%
schools[schools["Rank score (2017)"].isnull()]
# Out:
#       Unnamed: 0  index Rank  \
# 849          849    849  NaN
# 850          850    850  NaN
# 851          851    851  NaN
# 852          852    852  NaN
# 853          853    853  NaN
# 854          854    854  NaN
# 855          855    855  NaN
# 856          856    856  NaN
# 857          857    857  NaN
# 858          858    858  NaN
# 859          859    859  NaN
# 860          860    860  NaN
# 861          861    861  NaN
# 862          862    862  NaN
# 863          863    863  NaN
# 864          864    864  NaN
# 865          865    865  NaN
# 866          866    866  NaN
# 867          867    867  NaN
# 868          868    868  NaN
# 869          869    869  NaN
# 870          870    870  NaN
# 871          871    871  NaN
# 872          872    872  NaN
# 873          873    873  NaN
# 874          874    874  NaN
# 875          875    875  NaN
# 876          876    876  NaN
# 877          877    877  NaN
# 878          878    878  NaN
# ...          ...    ...  ...
# 1064        1064   1064  NaN
# 1065        1065   1065  NaN
# 1066        1066   1066  NaN
# 1067        1067   1067  NaN
# 1068        1068   1068  NaN
# 1069        1069   1069  NaN
# 1070        1070   1070  NaN
# 1071        1071   1071  NaN
# 1072        1072   1072  NaN
# 1073        1073   1073  NaN
# 1074        1074   1074  NaN
# 1075        1075   1075  NaN
# 1076        1076   1076  NaN
# 1077        1077   1077  NaN
# 1078        1078   1078  NaN
# 1079        1079   1079  NaN
# 1080        1080   1080  NaN
# 1081        1081   1081  NaN
# 1082        1082   1082  NaN
# 1083        1083   1083  NaN
# 1084        1084   1084  NaN
# 1085        1085   1085  NaN
# 1086        1086   1086  NaN
# 1087        1087   1087  NaN
# 1088        1088   1088  NaN
# 1089        1089   1089  NaN
# 1090        1090   1090  NaN
# 1091        1091   1091  NaN
# 1092        1092   1092  NaN
# 1093        1093   1093  NaN
#
#                                                District Grades  \
# 849                                 Lewiston Elementary    K-8
# 850                                           Taft City    K-8
# 851                     Napa County Office Of Education   K-12
# 852                 Mariposa County Office Of Education   K-12
# 853                              Bridgeville Elementary    K-8
# 854                             Bangor Union Elementary    K-8
# 855                        Linns Valley-Poso Flat Union    K-8
# 856            Baldy View Regional Occupational Program   9-12
# 857    Santa Clara County Regional Occupational Program  10-12
# 858          Glenn County Regional Occupational Program   9-12
# 859                                  Lincoln Elementary    K-6
# 860          Kings County Regional Occupational Program  10-12
# 861                            Bradley Union Elementary   K-12
# 862         Tehama County Regional Occupational Program  10-12
# 863     Santa Cruz County Regional Occupational Program  10-12
# 864                          Ravendale-Termo Elementary   K-12
# 865                           Flournoy Union Elementary    K-8
# 866                                     Mattole Unified   K-12
# 867                San Mateo County Office Of Education   K-12
# 868                            McCloud Union Elementary    K-8
# 869                          San Lucas Union Elementary    K-8
# 870                               Chowchilla Elementary    K-8
# 871                               Bolinas-Stinson Union    K-8
# 872                        Pope Valley Union Elementary    K-8
# 873    Long Beach Unified Regional Occupational Program  10-12
# 874                    Kings County Office Of Education   K-12
# 875                                    Blake Elementary    K-8
# 876                               McKittrick Elementary    K-8
# 877                                 Laytonville Unified   K-12
# 878                                   Elkins Elementary    K-8
# ...                                                 ...    ...
# 1064                                 Delphic Elementary   K-12
# 1065         Marin County Regional Occupational Program   9-12
# 1066                                     Denair Unified   K-12
# 1067                             Leggett Valley Unified   K-12
# 1068                                 Horicon Elementary    K-8
# 1069                               Farmersville Unified   K-12
# 1070                          Mountain Union Elementary    K-8
# 1071                        Big Lagoon Union Elementary    K-8
# 1072                            Mountain Valley Unified   K-12
# 1073                                Belridge Elementary    K-8
# 1074                              Desert Center Unified    K-8
# 1075            Southeast Regional Occupational Program   9-12
# 1076                    Yolo County Office Of Education   K-12
# 1077  State Board Of Education - Baypoint Preparator...   K-12
# 1078          Yolo County Regional Occupational Program   9-12
# 1079                          Stony Creek Joint Unified   K-12
# 1080             Yosemite Regional Occupational Program  11-12
# 1081                              Bret Harte Union High   9-12
# 1082                         Mt. Baldy Joint Elementary    K-8
# 1083           San Francisco County Office Of Education   K-12
# 1084          Lake County Regional Occupational Program   9-12
# 1085                        Mt. Shasta Union Elementary    K-8
# 1086                 Hart Regional Occupational Program   9-12
# 1087                      Happy Valley Union Elementary    K-8
# 1088                             Yreka Union Elementary    K-8
# 1089  California School For The Blind (State Special...   K-12
# 1090                Siskiyou County Office Of Education   K-12
# 1091                                   Bogus Elementary    K-8
# 1092                     Klamath River Union Elementary    K-8
# 1093                                  Canyon Elementary    K-8
#
#       # Elementary Schools  # Middle Schools  # High Schools  # Alt. Schools  \
# 849                      1                 0               0               0
# 850                      5                 1               0               0
# 851                      2                 0               2               0
# 852                      1                 0               0               2
# 853                      1                 0               0               0
# 854                      1                 0               0               0
# 855                      1                 0               0               0
# 856                      0                 0               1               0
# 857                      0                 0               1               0
# 858                      0                 0               1               0
# 859                      1                 0               0               0
# 860                      0                 0               1               0
# 861                      1                 0               0               1
# 862                      0                 0               1               0
# 863                      0                 0               1               0
# 864                      1                 0               0               2
# 865                      1                 0               0               0
# 866                      2                 0               1               1
# 867                      0                 0               4               2
# 868                      1                 0               0               0
# 869                      1                 0               0               0
# 870                      3                 2               0               0
# 871                      1                 0               0               0
# 872                      1                 0               0               0
# 873                      0                 0               1               0
# 874                      0                 0               2               1
# 875                      1                 0               0               0
# 876                      1                 0               0               0
# 877                      3                 0               2               0
# 878                      1                 0               0               0
# ...                    ...               ...             ...             ...
# 1064                     1                 0               0               0
# 1065                     0                 0               1               0
# 1066                     2                 1               1               1
# 1067                     2                 0               2               0
# 1068                     1                 0               0               0
# 1069                     3                 1               2               0
# 1070                     1                 0               0               0
# 1071                     1                 0               0               0
# 1072                     2                 0               2               0
# 1073                     1                 0               0               0
# 1074                     1                 0               0               0
# 1075                     0                 0               1               0
# 1076                     1                 0               2               1
# 1077                     0                 0               0               1
# 1078                     0                 0               1               0
# 1079                     1                 1               2               0
# 1080                     0                 0               1               0
# 1081                     0                 0               3               0
# 1082                     1                 0               0               0
# 1083                     0                 0               0               4
# 1084                     0                 0               1               0
# 1085                     2                 0               0               0
# 1086                     0                 0               1               0
# 1087                     3                 0               0               0
# 1088                     3                 0               0               0
# 1089                     0                 0               0               1
# 1090                     0                 0               0               3
# 1091                     1                 0               0               0
# 1092                     1                 0               0               0
# 1093                     1                 0               0               0
#
#                   City          County  Rank score (2017)  Rank (2016)  rank
# 849           Lewiston         Trinity                NaN          NaN     0
# 850               Taft            Kern                NaN          NaN     0
# 851               Napa            Napa                NaN          NaN     0
# 852           Mariposa        Mariposa                NaN          NaN     0
# 853        Bridgeville        Humboldt                NaN          NaN     0
# 854             Bangor           Butte                NaN          NaN     0
# 855         Glennville            Kern                NaN          NaN     0
# 856            Ontario  San Bernardino                NaN          NaN     0
# 857          Sunnyvale     Santa Clara                NaN          NaN     0
# 858            Willows           Glenn                NaN          NaN     0
# 859           Petaluma          Sonoma                NaN          NaN     0
# 860            Lemoore           Kings                NaN          NaN     0
# 861            Bradley        Monterey                NaN          NaN     0
# 862          Red Bluff          Tehama                NaN          NaN     0
# 863         Santa Cruz      Santa Cruz                NaN          NaN     0
# 864          Ravendale          Lassen                NaN          NaN     0
# 865           Flournoy          Tehama                NaN          NaN     0
# 866           Petrolia        Humboldt                NaN          NaN     0
# 867       Redwood City       San Mateo                NaN          NaN     0
# 868            McCloud        Siskiyou                NaN          NaN     0
# 869          San Lucas        Monterey                NaN          NaN     0
# 870         Chowchilla          Madera                NaN          NaN     0
# 871            Bolinas           Marin                NaN          NaN     0
# 872        Pope Valley            Napa                NaN          NaN     0
# 873         Long Beach     Los Angeles                NaN          NaN     0
# 874            Hanford           Kings                NaN          NaN     0
# 875              Woody            Kern                NaN          NaN     0
# 876        Mc Kittrick            Kern                NaN          NaN     0
# 877        Laytonville       Mendocino                NaN          NaN     0
# 878           Paskenta          Tehama                NaN          NaN     0
# ...                ...             ...                ...          ...   ...
# 1064          Montague        Siskiyou                NaN          NaN     0
# 1065        San Rafael           Marin                NaN          NaN     0
# 1066            Denair      Stanislaus                NaN          NaN     0
# 1067           Leggett       Mendocino                NaN          NaN     0
# 1068         Annapolis          Sonoma                NaN          NaN     0
# 1069      Farmersville          Tulare                NaN          NaN     0
# 1070  Montgomery Creek          Shasta                NaN          NaN     0
# 1071          Trinidad        Humboldt                NaN          NaN     0
# 1072           Hayfork         Trinity                NaN          NaN     0
# 1073       Mc Kittrick            Kern                NaN          NaN     0
# 1074     Desert Center       Riverside                NaN          NaN     0
# 1075          Cerritos     Los Angeles                NaN          NaN     0
# 1076          Woodland            Yolo                NaN          NaN     0
# 1077             Hemet       Riverside                NaN          NaN     0
# 1078          Woodland            Yolo                NaN          NaN     0
# 1079         Elk Creek           Glenn                NaN          NaN     0
# 1080           Modesto      Stanislaus                NaN          NaN     0
# 1081       Angels Camp       Calaveras                NaN          NaN     0
# 1082          Mt Baldy  San Bernardino                NaN          NaN     0
# 1083     San Francisco   San Francisco                NaN          NaN     0
# 1084          Lakeport            Lake                NaN          NaN     0
# 1085      Mount Shasta        Siskiyou                NaN          NaN     0
# 1086     Santa Clarita     Los Angeles                NaN          NaN     0
# 1087          Anderson          Shasta                NaN          NaN     0
# 1088             Yreka        Siskiyou                NaN          NaN     0
# 1089           Fremont         Alameda                NaN          NaN     0
# 1090             Yreka        Siskiyou                NaN          NaN     0
# 1091          Montague        Siskiyou                NaN          NaN     0
# 1092       Horse Creek        Siskiyou                NaN          NaN     0
# 1093            Canyon    Contra Costa                NaN          NaN     0
#
# [245 rows x 14 columns]

# %%
len(schools[schools["Rank score (2017)"].isnull()])
# Out:
# 245

# %%
len(schools)
# Out:
# 1094

# %%
schools[schools["County"] == 'Amador']
# Out:
#      Unnamed: 0  index   Rank                                     District  \
# 419         419    419  422nd                        Amador County Unified
# 770         770    770  774th            Amador County Office Of Education
# 978         978    978    NaN  Amador County Regional Occupational Program
#
#     Grades  # Elementary Schools  # Middle Schools  # High Schools  \
# 419   K-12                     6                 2               3
# 770   K-12                     0                 1               0
# 978     12                     0                 0               1
#
#      # Alt. Schools     City  County  Rank score (2017)  Rank (2016)  rank
# 419               1  Jackson  Amador               0.51        505.0   422
# 770               2  Jackson  Amador               0.22          NaN   774
# 978               0  Jackson  Amador                NaN          NaN     0

# %%
schools.head()
# Out:
#    Unnamed: 0  index Rank                    District Grades  \
# 0           0      0  1st     Orinda Union Elementary    K-8
# 1           1      1  2nd          San Marino Unified   K-12
# 2           2      2  3rd  Rancho Santa Fe Elementary    K-8
# 3           3      3  4th  Montecito Union Elementary    K-6
# 4           4      4  5th           La Canada Unified   K-12
#
#    # Elementary Schools  # Middle Schools  # High Schools  # Alt. Schools  \
# 0                     4                 1               0               0
# 1                     2                 1               1               0
# 2                     1                 1               0               0
# 3                     1                 0               0               0
# 4                     3                 0               1               0
#
#               City         County  Rank score (2017)  Rank (2016)  rank
# 0           Orinda   Contra Costa              0.989          3.0     1
# 1       San Marino    Los Angeles              0.989          6.0     2
# 2  Rancho Santa Fe      San Diego              0.985         10.0     3
# 3    Santa Barbara  Santa Barbara              0.985          2.0     4
# 4        La Canada    Los Angeles              0.983          4.0     5

# %%
schools_by_county[schools_by_county["Rank score (2017)"].isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-9c8289f74894> in <module>()
# ----> 1 schools_by_county[schools_by_county["Rank score (2017)"].isnull()]
#
# NameError: name 'schools_by_county' is not defined

# %%
schools_by_county = schools[['County', 'Rank score (2017)']].groupby("County").aggregate(np.nanmean).reset_index()
schools_by_county.head()
# Out:
# /Users/kanamishra/anaconda3/lib/python3.5/site-packages/pandas/core/groupby.py:842: RuntimeWarning: Mean of empty slice
#   f = lambda x: func(x, *args, **kwargs)
#       County  Rank score (2017)
# 0    Alameda           0.625222
# 1     Alpine           0.103000
# 2     Amador           0.365000
# 3      Butte           0.456600
# 4  Calaveras           0.510000

# %%
schools_by_county
# Out:
#              County  Rank score (2017)
# 0           Alameda           0.625222
# 1            Alpine           0.103000
# 2            Amador           0.365000
# 3             Butte           0.456600
# 4         Calaveras           0.510000
# 5            Colusa           0.484750
# 6      Contra Costa           0.632706
# 7         Del Norte           0.301000
# 8         El Dorado           0.624643
# 9            Fresno           0.357968
# 10            Glenn           0.466833
# 11         Humboldt           0.544190
# 12         Imperial           0.467063
# 13             Inyo           0.359200
# 14             Kern           0.351000
# 15            Kings           0.465083
# 16             Lake           0.315800
# 17           Lassen           0.476714
# 18      Los Angeles           0.582235
# 19           Madera           0.466778
# 20            Marin           0.768923
# 21         Mariposa           0.550000
# 22        Mendocino           0.351571
# 23           Merced           0.370600
# 24            Modoc           0.355000
# 25             Mono           0.492000
# 26         Monterey           0.400421
# 27             Napa           0.614000
# 28           Nevada           0.651500
# 29           Orange           0.673929
# 30           Placer           0.680231
# 31           Plumas           0.540000
# 32        Riverside           0.410261
# 33       Sacramento           0.427231
# 34       San Benito           0.591667
# 35   San Bernardino           0.411438
# 36        San Diego           0.605400
# 37    San Francisco           0.592000
# 38      San Joaquin           0.462733
# 39  San Luis Obispo           0.561700
# 40        San Mateo           0.745182
# 41    Santa Barbara           0.617524
# 42      Santa Clara           0.699161
# 43       Santa Cruz           0.714929
# 44           Shasta           0.599875
# 45           Sierra                NaN
# 46         Siskiyou           0.441500
# 47           Solano           0.455625
# 48           Sonoma           0.581743
# 49       Stanislaus           0.470250
# 50           Sutter           0.583083
# 51           Tehama           0.388545
# 52          Trinity           0.759000
# 53           Tulare           0.307892
# 54         Tuolumne           0.461900
# 55          Ventura           0.492842
# 56             Yolo           0.464400
# 57             Yuba           0.555800

# %%
len(schools_by_county)
# Out:
# 58

# %%
tracts_school = pd.merge(tracts_with_county, schools_by_county, how='left', left_on='NAME', right_on='County')

# %%
tracts_school.head()
# Out:
#   COUNTYFP      GEOID_x    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0      001  06001442700  1234034       0  +37.5371514  -122.0081094
# 1      001  06001442800  1278647       0  +37.5293619  -121.9931002
# 2      037  06037204920   909972       0  +34.0175004  -118.1974975
# 3      037  06037205110   286962       0  +34.0245059  -118.2142985
# 4      037  06037205120  1466129       0  +34.0187546  -118.2117956
#
#                                             geometry        tract  blkgrps  \
# 0  POLYGON ((-122.017211 37.539323, -122.017186 3...  06001442700      3.0
# 1  POLYGON ((-122.002301 37.529836, -122.002236 3...  06001442800      1.0
# 2  POLYGON ((-118.202837 34.019657, -118.202829 3...  06037204920      2.0
# 3  POLYGON ((-118.219635 34.026285, -118.219449 3...  06037205110      1.0
# 4  POLYGON ((-118.220227 34.020564, -118.220183 3...  06037205120      2.0
#
#    population        ...          median_smoc  median_gross_rent  \
# 0      3275.0        ...               2581.0             1294.0
# 1      3056.0        ...               2303.0             1958.0
# 2      2570.0        ...               1605.0             1067.0
# 3      3826.0        ...                  NaN             1140.0
# 4      3288.0        ...                  NaN              766.0
#
#    pct_owner_occupied_hu  pct_renter_occupied_hu  COUNTYNS  GEOID_y  \
# 0                   75.0                    25.0  01675839    06001
# 1                   71.0                    29.0  01675839    06001
# 2                   48.0                    52.0  00277283    06037
# 3                    0.0                   100.0  00277283    06037
# 4                   12.0                    88.0  00277283    06037
#
#           NAME            NAMELSAD       County  Rank score (2017)
# 0      Alameda      Alameda County      Alameda           0.625222
# 1      Alameda      Alameda County      Alameda           0.625222
# 2  Los Angeles  Los Angeles County  Los Angeles           0.582235
# 3  Los Angeles  Los Angeles County  Los Angeles           0.582235
# 4  Los Angeles  Los Angeles County  Los Angeles           0.582235
#
# [5 rows x 69 columns]

# %%
tracts_school["GEOID_x"].nunique()
# Out:
# 8057

# %%
len(tracts_school)
# Out:
# 8057

# %%
tracts_school.columns
# Out:
# Index(['COUNTYFP', 'GEOID_x', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON',
#        'geometry', 'tract', 'blkgrps', 'population', 'households',
#        'land_acres', 'ht_ami', 'ht_80ami', 'ht_nmi', 'h_ami', 'h_80ami',
#        'h_nmi', 't_ami', 't_80ami', 't_nmi', 'co2_per_hh_local',
#        'co2_per_acre_local', 'autos_per_hh_ami', 'autos_per_hh_80ami',
#        'autos_per_hh_nmi', 'vmt_per_hh_ami', 'vmt_per_hh_80ami',
#        'vmt_per_hh_nmi', 'pct_transit_commuters_ami',
#        'pct_transit_commuters_80ami', 'pct_transit_commuters_nmi',
#        't_cost_ami', 't_cost_80ami', 't_cost_nmi', 'auto_ownership_cost_ami',
#        'auto_ownership_cost_80ami', 'auto_ownership_cost_nmi', 'vmt_cost_ami',
#        'vmt_cost_80ami', 'vmt_cost_nmi', 'transit_cost_ami',
#        'transit_cost_80ami', 'transit_cost_nmi', 'transit_trips_ami',
#        'transit_trips_80ami', 'transit_trips_nmi', 'compact_ndx',
#        'emp_ovrll_ndx', 'res_density', 'gross_hh_density', 'hh_gravity',
#        'frac_sfd', 'emp_gravity', 'emp_ndx', 'block_size',
#        'intersection_density', 'avg_block_perimeter_meters', 'h_cost',
#        'median_smoc', 'median_gross_rent', 'pct_owner_occupied_hu',
#        'pct_renter_occupied_hu', 'COUNTYNS', 'GEOID_y', 'NAME', 'NAMELSAD',
#        'County', 'Rank score (2017)'],
#       dtype='object')

# %%
crimes.head()
# Out:
#    Unnamed: 0     County  Violent_sum  Property_sum
# 0           0    Alameda        10127         59744
# 1           1     Alpine            6            34
# 2           2     Amador           92           669
# 3           3      Butte          790          7307
# 4           4  Calaveras          178           656

# %%
tracts_final = pd.merge(tracts_school, crimes, how='left', on = 'County')
tracts_final.head()
# Out:
#   COUNTYFP      GEOID_x    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0      001  06001442700  1234034       0  +37.5371514  -122.0081094
# 1      001  06001442800  1278647       0  +37.5293619  -121.9931002
# 2      037  06037204920   909972       0  +34.0175004  -118.1974975
# 3      037  06037205110   286962       0  +34.0245059  -118.2142985
# 4      037  06037205120  1466129       0  +34.0187546  -118.2117956
#
#                                             geometry        tract  blkgrps  \
# 0  POLYGON ((-122.017211 37.539323, -122.017186 3...  06001442700      3.0
# 1  POLYGON ((-122.002301 37.529836, -122.002236 3...  06001442800      1.0
# 2  POLYGON ((-118.202837 34.019657, -118.202829 3...  06037204920      2.0
# 3  POLYGON ((-118.219635 34.026285, -118.219449 3...  06037205110      1.0
# 4  POLYGON ((-118.220227 34.020564, -118.220183 3...  06037205120      2.0
#
#    population      ...       pct_renter_occupied_hu  COUNTYNS  GEOID_y  \
# 0      3275.0      ...                         25.0  01675839    06001
# 1      3056.0      ...                         29.0  01675839    06001
# 2      2570.0      ...                         52.0  00277283    06037
# 3      3826.0      ...                        100.0  00277283    06037
# 4      3288.0      ...                         88.0  00277283    06037
#
#           NAME            NAMELSAD       County  Rank score (2017)  \
# 0      Alameda      Alameda County      Alameda           0.625222
# 1      Alameda      Alameda County      Alameda           0.625222
# 2  Los Angeles  Los Angeles County  Los Angeles           0.582235
# 3  Los Angeles  Los Angeles County  Los Angeles           0.582235
# 4  Los Angeles  Los Angeles County  Los Angeles           0.582235
#
#    Unnamed: 0  Violent_sum  Property_sum
# 0           0        10127         59744
# 1           0        10127         59744
# 2          18        56351        252224
# 3          18        56351        252224
# 4          18        56351        252224
#
# [5 rows x 72 columns]

# %%
len(tracts_final)
# Out:
# 8057

# %%
tracts_final.drop("GEOID_y", axis = 1, inplace=True)

# %%
tracts_final.rename(columns={"GEOID_x" : "GEOID"}, inplace=True)

# %%
tracts_final.head()
# Out:
#   COUNTYFP        GEOID    ALAND  AWATER     INTPTLAT      INTPTLON  \
# 0      001  06001442700  1234034       0  +37.5371514  -122.0081094
# 1      001  06001442800  1278647       0  +37.5293619  -121.9931002
# 2      037  06037204920   909972       0  +34.0175004  -118.1974975
# 3      037  06037205110   286962       0  +34.0245059  -118.2142985
# 4      037  06037205120  1466129       0  +34.0187546  -118.2117956
#
#                                             geometry        tract  blkgrps  \
# 0  POLYGON ((-122.017211 37.539323, -122.017186 3...  06001442700      3.0
# 1  POLYGON ((-122.002301 37.529836, -122.002236 3...  06001442800      1.0
# 2  POLYGON ((-118.202837 34.019657, -118.202829 3...  06037204920      2.0
# 3  POLYGON ((-118.219635 34.026285, -118.219449 3...  06037205110      1.0
# 4  POLYGON ((-118.220227 34.020564, -118.220183 3...  06037205120      2.0
#
#    population      ...       pct_owner_occupied_hu  pct_renter_occupied_hu  \
# 0      3275.0      ...                        75.0                    25.0
# 1      3056.0      ...                        71.0                    29.0
# 2      2570.0      ...                        48.0                    52.0
# 3      3826.0      ...                         0.0                   100.0
# 4      3288.0      ...                        12.0                    88.0
#
#    COUNTYNS         NAME            NAMELSAD       County  Rank score (2017)  \
# 0  01675839      Alameda      Alameda County      Alameda           0.625222
# 1  01675839      Alameda      Alameda County      Alameda           0.625222
# 2  00277283  Los Angeles  Los Angeles County  Los Angeles           0.582235
# 3  00277283  Los Angeles  Los Angeles County  Los Angeles           0.582235
# 4  00277283  Los Angeles  Los Angeles County  Los Angeles           0.582235
#
#    Unnamed: 0  Violent_sum  Property_sum
# 0           0        10127         59744
# 1           0        10127         59744
# 2          18        56351        252224
# 3          18        56351        252224
# 4          18        56351        252224
#
# [5 rows x 71 columns]

# %%
tracts_final.columns
# Out:
# Index(['COUNTYFP', 'GEOID', 'ALAND', 'AWATER', 'INTPTLAT', 'INTPTLON',
#        'geometry', 'tract', 'blkgrps', 'population', 'households',
#        'land_acres', 'ht_ami', 'ht_80ami', 'ht_nmi', 'h_ami', 'h_80ami',
#        'h_nmi', 't_ami', 't_80ami', 't_nmi', 'co2_per_hh_local',
#        'co2_per_acre_local', 'autos_per_hh_ami', 'autos_per_hh_80ami',
#        'autos_per_hh_nmi', 'vmt_per_hh_ami', 'vmt_per_hh_80ami',
#        'vmt_per_hh_nmi', 'pct_transit_commuters_ami',
#        'pct_transit_commuters_80ami', 'pct_transit_commuters_nmi',
#        't_cost_ami', 't_cost_80ami', 't_cost_nmi', 'auto_ownership_cost_ami',
#        'auto_ownership_cost_80ami', 'auto_ownership_cost_nmi', 'vmt_cost_ami',
#        'vmt_cost_80ami', 'vmt_cost_nmi', 'transit_cost_ami',
#        'transit_cost_80ami', 'transit_cost_nmi', 'transit_trips_ami',
#        'transit_trips_80ami', 'transit_trips_nmi', 'compact_ndx',
#        'emp_ovrll_ndx', 'res_density', 'gross_hh_density', 'hh_gravity',
#        'frac_sfd', 'emp_gravity', 'emp_ndx', 'block_size',
#        'intersection_density', 'avg_block_perimeter_meters', 'h_cost',
#        'median_smoc', 'median_gross_rent', 'pct_owner_occupied_hu',
#        'pct_renter_occupied_hu', 'COUNTYNS', 'NAME', 'NAMELSAD', 'County',
#        'Rank score (2017)', 'Unnamed: 0', 'Violent_sum', 'Property_sum'],
#       dtype='object')

# %%
tracts_final.to_csv("tracts_updated.csv")

# %%
print("test")
# Out:
# test
